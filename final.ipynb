# %%
import pandas as pd
covid = 'C:\\Users\\Admin\\Downloads\\2019_nCoV_data.csv'
covids = pd.read_csv(covid)

# %%
covids.head()
# Out:
#    Sno                 Date Province/State Country          Last Update  \
# 0    1  01/22/2020 12:00:00          Anhui   China  01/22/2020 12:00:00
# 1    2  01/22/2020 12:00:00        Beijing   China  01/22/2020 12:00:00
# 2    3  01/22/2020 12:00:00      Chongqing   China  01/22/2020 12:00:00
# 3    4  01/22/2020 12:00:00         Fujian   China  01/22/2020 12:00:00
# 4    5  01/22/2020 12:00:00          Gansu   China  01/22/2020 12:00:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
covids.isnull().any()
# Out:
# Sno               False
# Date              False
# Province/State     True
# Country           False
# Last Update       False
# Confirmed         False
# Deaths            False
# Recovered         False
# dtype: bool

# %%
covids['Province/State']=covids['Province/State'].fillna('None')

# %%
covids.isnull().any()
# Out:
# Sno               False
# Date              False
# Province/State    False
# Country           False
# Last Update       False
# Confirmed         False
# Deaths            False
# Recovered         False
# dtype: bool

# %%
covids
# Out:
#        Sno                 Date   Province/State Country          Last Update  \
# 0        1  01/22/2020 12:00:00            Anhui   China  01/22/2020 12:00:00
# 1        2  01/22/2020 12:00:00          Beijing   China  01/22/2020 12:00:00
# 2        3  01/22/2020 12:00:00        Chongqing   China  01/22/2020 12:00:00
# 3        4  01/22/2020 12:00:00           Fujian   China  01/22/2020 12:00:00
# 4        5  01/22/2020 12:00:00            Gansu   China  01/22/2020 12:00:00
# ...    ...                  ...              ...     ...                  ...
# 1714  1715  02/17/2020 22:00:00      Madison, WI      US  2020-02-05T21:53:02
# 1715  1716  02/17/2020 22:00:00       Orange, CA      US  2020-02-01T19:53:03
# 1716  1717  02/17/2020 22:00:00  San Antonio, TX      US  2020-02-13T18:53:02
# 1717  1718  02/17/2020 22:00:00      Seattle, WA      US  2020-02-09T07:03:04
# 1718  1719  02/17/2020 22:00:00        Tempe, AZ      US  2020-02-01T19:43:03
#
# ...

# %%
covids.groupby('Country').max().res
# Out:
#                        Sno                 Date                Province/State  \
# Country
# Australia             1696  02/17/2020 22:00:00                      Victoria
# Belgium               1704  02/17/2020 22:00:00                          None
# Brazil                  83  01/23/2020 12:00:00                          None
# Cambodia              1705  02/17/2020 22:00:00                          None
# Canada                1706  02/17/2020 22:00:00                   Toronto, ON
# China                   35  01/22/2020 12:00:00                      Zhejiang
# Egypt                 1707  02/17/2020 22:00:00                          None
# Finland               1708  02/17/2020 22:00:00                          None
# France                1685  02/17/2020 22:00:00                          None
# Germany               1683  02/17/2020 22:00:00                          None
# Hong Kong             1677  02/17/2020 22:00:00                     Hong Kong
# ...

# %%
covids1 = covids[covids['Country']!='Mainland China']

# %%
covids1
# Out:
#        Sno                 Date   Province/State Country          Last Update  \
# 0        1  01/22/2020 12:00:00            Anhui   China  01/22/2020 12:00:00
# 1        2  01/22/2020 12:00:00          Beijing   China  01/22/2020 12:00:00
# 2        3  01/22/2020 12:00:00        Chongqing   China  01/22/2020 12:00:00
# 3        4  01/22/2020 12:00:00           Fujian   China  01/22/2020 12:00:00
# 4        5  01/22/2020 12:00:00            Gansu   China  01/22/2020 12:00:00
# ...    ...                  ...              ...     ...                  ...
# 1714  1715  02/17/2020 22:00:00      Madison, WI      US  2020-02-05T21:53:02
# 1715  1716  02/17/2020 22:00:00       Orange, CA      US  2020-02-01T19:53:03
# 1716  1717  02/17/2020 22:00:00  San Antonio, TX      US  2020-02-13T18:53:02
# 1717  1718  02/17/2020 22:00:00      Seattle, WA      US  2020-02-09T07:03:04
# 1718  1719  02/17/2020 22:00:00        Tempe, AZ      US  2020-02-01T19:43:03
#
# ...

# %%
covids2 = covids[covids['Country']=='Mainland China']

# %%
covids2
# Out:
#        Sno                 Date  Province/State         Country  \
# 38      39  01/23/2020 12:00:00           Anhui  Mainland China
# 39      40  01/23/2020 12:00:00         Beijing  Mainland China
# 40      41  01/23/2020 12:00:00       Chongqing  Mainland China
# 41      42  01/23/2020 12:00:00          Fujian  Mainland China
# 42      43  01/23/2020 12:00:00           Gansu  Mainland China
# ...    ...                  ...             ...             ...
# 1672  1673  02/17/2020 22:00:00        Xinjiang  Mainland China
# 1673  1674  02/17/2020 22:00:00  Inner Mongolia  Mainland China
# 1674  1675  02/17/2020 22:00:00         Ningxia  Mainland China
# 1681  1682  02/17/2020 22:00:00         Qinghai  Mainland China
# 1708  1709  02/17/2020 22:00:00           Tibet  Mainland China
#
#               Last Update  Confirmed  Deaths  Recovered
# 38    01/23/2020 12:00:00        9.0     0.0        0.0
# 39    01/23/2020 12:00:00       22.0     0.0        0.0
# ...

# %%
from matplotlib import pyplot as plt

# %%
plt.bar(covids1.iloc[:,3],covids1.iloc[:,5],tick_label=covids1.iloc[:,4])
# Out:
# <BarContainer object of 918 artists>

# %%
plt.bar(covids2.iloc[:,2],covids2.iloc[:,5],tick_label=covids2.iloc[:,4])
# Out:
# <BarContainer object of 801 artists>
